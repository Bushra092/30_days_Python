# %% [markdown]
# 🔁 Practice Problems for Day 1–13
# Day 1: Basics
# 🔸 Print a triangle pattern using *:
#
# python
# Copy
# Edit
# ##### Output
# ##### *
# ##### **
# ##### ***
# ##### ****
# ##### *****
#
#
#
# Day 2: Variables & Data Types
# 🔸 Convert user-entered temperature from Celsius to Fahrenheit and vice versa.
# ---
#
# Day 3: Lists, Tuples, Dictionaries
# 🔸 Make a student grade tracker:
#
# python
# Copy
# Edit
# grades = {"Alice": 88, "Bob": 75, "Charlie": 95}
# # Add a new student, update a score, find the student with the highest grade
# 🔸 Reverse a tuple manually (without using [::-1]).
# ---
#
# Day 4: Control Structures
# 🔸 FizzBuzz (print numbers from 1 to 100. For multiples of 3 print "Fizz", for 5 "Buzz", for both "FizzBuzz").
#
# 🔸 Print all prime numbers between 1 and 100.
# ---
#
# Day 5: Functions
# 🔸 Write a function that accepts a list and returns:
#
# Total sum
#
# Average
#
# Count of even numbers
#
# 🔸 Write a lambda function to check if a number is a palindrome.
#
# Day 6: Modules and Packages
# 🔸 Use the random module to simulate a dice roll 100 times and count frequency of each face (1–6).
#
# 🔸 Write a custom module called geometry with:
#
# area_of_circle(radius)
#
# perimeter_of_square(side)
# ---
#
# Day 7: File Handling
# 🔸 Write and read from a .csv file that stores names and emails.
#
# 🔸 Given a .txt file, count:
#
# Total number of words
#
# Most frequent word
# ---
#
# Day 8: OOP – Part 1
# 🔸 Create a class Book with attributes like title, author, pages. Add method is_thick() which returns True if pages > 300.
#
# Day 9: OOP – Part 2
# 🔸 Create Employee class and subclass Manager. Include a method in Manager to return how many employees they supervise.
#
# 🔸 Practice method overriding and using super().
# ---
#
# Day 10: Exception Handling
# 🔸 Create a calculator that handles division by zero, invalid input (e.g., letters), and continues until the user exits.
# ---
#
# Day 11: Date & Time
# 🔸 Build a birthday calculator: Take birthdate as input and tell the user how many days left for their next birthday.
#
# 🔸 Create a simple stopwatch using time module.
# ---
#
# Day 12: Regex
# 🔸 Validate:
#
# Phone number (Indian): +91-XXXXXXXXXX
#
# Strong password (at least one uppercase, one number, one special character)
#
# 🔸 Extract all email IDs from a given text paragraph.
# ---
#
# Day 13: Data Structures (Stacks & Queues)
# 🔸 Implement a browser history using a stack.
#
# 🔸 Simulate a queue of customers at a bank using list operations.
# ---
#
# ✨ Bonus Mini Projects (Mix of Concepts)
# To-Do App (CLI)
#
# Add, remove, and mark tasks as done.
#
# Save tasks in a file.
#
# Simple Banking System
#
# Create classes for Account, Customer.
#
# Allow deposit, withdrawal, and transaction history.
#
# Password Generator
#
# Include options: length, include symbols/numbers.
